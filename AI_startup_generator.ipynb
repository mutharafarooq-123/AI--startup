# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
import sys
# !{sys.executable} -m pip install groq

from groq import Groq
import gradio as gr

# 🔑 Your Groq API key
client = Groq(api_key="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")

def generate_startup_plan(user_input):
    prompt = f"""
You are a startup expert.

Create a startup plan for:
{user_input}

Give:
1. Startup Idea
2. Market Research
3. Business Plan
4. Pitch
"""

    try:
        response = client.chat.completions.create(
            model="llama-3.1-8b-instant",   # ✅ WORKING MODEL
            messages=[{"role": "user", "content": prompt}]
        )
        return response.choices[0].message.content

    except Exception as e:
        return f"Error: {str(e)}"


def run_app(text):
    if not text.strip():
        return "Please enter a valid idea"
    return generate_startup_plan(text)


gr.Interface(
    fn=run_app,
    inputs="text",
    outputs="text",
    title="🚀 AI Startup Idea Generator (Groq)"
).launch(share=True)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.3/142.3 kB 1.4 MB/s eta 0:00:00
# ...
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://f165bd0ef1bda40c28.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f165bd0ef1bda40c28.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
